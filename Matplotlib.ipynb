# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
xpoints = np.array([1,2])
ypoints =np.array([5,10])
plt.plot(xpoints,ypoints)

# %%
xpoints = np.array([1,20])
ypoints =np.array([10,200])
plt.plot(xpoints,ypoints)

# %%
xpoints = np.array([1,6])
ypoints =np.array([4,5])
plt.plot(xpoints,ypoints,'X')

# %%
xpoints = np.array([1,6])
ypoints =np.array([4,5])
plt.plot(xpoints,ypoints,'o')

# %%
ypoints = np.array([3,8,1,10])
plt.plot(ypoints,'*' 'r')

# %%
ypoints = np.array([3,8,1,12])
xpoints = np.array([5,6,7,9])
plt.plot(xpoints,ypoints,marker='*',color='blue', ms= 10, linewidth=2,linestyle= '--',markerfacecolor ='red',markeredgecolor='black')

# %%
ypoints = np.array([3,8,1,12])
y2points = np.array([5,6,7,9])
plt.plot(ypoints)
plt.plot(y2points)

# %%
plt.scatter(ypoints,y2points)

# %%
plt.bar(ypoints,y2points)
# Out:
# <BarContainer object of 4 artists>

# %%
plt.hist(ypoints)
# Out:
# (array([1., 1., 0., 0., 0., 0., 1., 0., 0., 1.]),
#  array([ 1. ,  2.1,  3.2,  4.3,  5.4,  6.5,  7.6,  8.7,  9.8, 10.9, 12. ]),
#  <a list of 10 Patch objects>)

# %%
y=np.array([10,25,15,10])
mylabels=['a','b','c','d']
mycolors=['hotpink','red','orange','green']
myexplode=[0,0.2,0.8,0.6]
plt.pie(y,labels=mylabels,colors=mycolors,explode=myexplode,startangle=0)
# Out:
# ([<matplotlib.patches.Wedge at 0x7f8ff5790190>,
# ...
#  [Text(0.9526279355804298, 0.5500000148652441, 'a'),
#   Text(-0.9192388155425117, 0.919238815542512, 'b'),
#   Text(-0.4917562429712407, -1.8352590546020502, 'c'),
#   Text(1.472243173169755, -0.8500000229735594, 'd')])

# %%
plt.pie(y,colors=mycolors)
plt.legend(labels=mylabels)
